# %%
# %pip install kagglehub opencv-python numpy matplotlib gdown openvino numpy pyautogui
# Out:
# Requirement already satisfied: kagglehub in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (0.3.12)
# Requirement already satisfied: opencv-python in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (2.2.6)
# Requirement already satisfied: matplotlib in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (3.10.3)
# Requirement already satisfied: gdown in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (5.2.0)
# Requirement already satisfied: openvino in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (2025.1.0)
# Requirement already satisfied: pyautogui in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (0.9.54)
# Collecting PyQt6
#   Downloading pyqt6-6.9.1-cp39-abi3-win_amd64.whl.metadata (2.2 kB)
# Requirement already satisfied: packaging in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from kagglehub) (2.32.4)
# Requirement already satisfied: tqdm in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: beautifulsoup4 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from gdown) (3.18.0)
# Requirement already satisfied: openvino-telemetry>=2023.2.1 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from openvino) (2025.1.0)
# Requirement already satisfied: pymsgbox in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from pyautogui) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from pyautogui) (1.0.1)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from pyautogui) (0.1.3)
# Collecting PyQt6-sip<14,>=13.8 (from PyQt6)
#   Downloading pyqt6_sip-13.10.2-cp313-cp313-win_amd64.whl.metadata (515 bytes)
# Collecting PyQt6-Qt6<6.10.0,>=6.9.0 (from PyQt6)
#   Downloading pyqt6_qt6-6.9.1-py3-none-win_amd64.whl.metadata (551 bytes)
# Requirement already satisfied: pyrect in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from beautifulsoup4->gdown) (4.14.0)
# Requirement already satisfied: pyperclip in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from mouseinfo->pyautogui) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from requests->kagglehub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from requests->kagglehub) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from requests->kagglehub) (2025.6.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in c:\users\vijay\desktop\gesture control system\.venv\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading pyqt6-6.9.1-cp39-abi3-win_amd64.whl (25.7 MB)
#    ---------------------------------------- 0.0/25.7 MB ? eta -:--:--
#    - -------------------------------------- 0.8/25.7 MB 8.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 2.6/25.7 MB 13.8 MB/s eta 0:00:02
#    ------------- -------------------------- 8.7/25.7 MB 17.3 MB/s eta 0:00:01
#    ------------------- -------------------- 12.6/25.7 MB 18.1 MB/s eta 0:00:01
#    -------------------------- ------------- 17.3/25.7 MB 19.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 22.3/25.7 MB 20.0 MB/s eta 0:00:01
#    ---------------------------------------  25.7/25.7 MB 20.2 MB/s eta 0:00:01
#    ---------------------------------------- 25.7/25.7 MB 17.7 MB/s eta 0:00:00
# Downloading pyqt6_qt6-6.9.1-py3-none-win_amd64.whl (73.8 MB)
#    ---------------------------------------- 0.0/73.8 MB ? eta -:--:--
#    -- ------------------------------------- 5.0/73.8 MB 24.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 8.7/73.8 MB 25.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 11.0/73.8 MB 18.2 MB/s eta 0:00:04
#    ------- -------------------------------- 13.4/73.8 MB 18.1 MB/s eta 0:00:04
#    -------- ------------------------------- 16.0/73.8 MB 15.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 18.6/73.8 MB 15.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 21.0/73.8 MB 14.7 MB/s eta 0:00:04
#    ------------ --------------------------- 23.6/73.8 MB 14.4 MB/s eta 0:00:04
#    -------------- ------------------------- 26.5/73.8 MB 14.2 MB/s eta 0:00:04
#    --------------- ------------------------ 29.4/73.8 MB 14.1 MB/s eta 0:00:04
#    ----------------- ---------------------- 31.7/73.8 MB 14.0 MB/s eta 0:00:04
#    ------------------ --------------------- 34.9/73.8 MB 13.9 MB/s eta 0:00:03
#    -------------------- ------------------- 37.2/73.8 MB 13.8 MB/s eta 0:00:03
#    --------------------- ------------------ 39.3/73.8 MB 13.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 41.4/73.8 MB 13.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 43.5/73.8 MB 13.1 MB/s eta 0:00:03
#    ------------------------ --------------- 45.6/73.8 MB 12.9 MB/s eta 0:00:03
#    ------------------------- -------------- 47.7/73.8 MB 12.8 MB/s eta 0:00:03
#    --------------------------- ------------ 49.8/73.8 MB 12.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 51.9/73.8 MB 12.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 53.5/73.8 MB 12.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 54.8/73.8 MB 12.1 MB/s eta 0:00:02
#    ------------------------------ --------- 56.1/73.8 MB 11.8 MB/s eta 0:00:02
#    ------------------------------- -------- 57.4/73.8 MB 11.6 MB/s eta 0:00:02
#    ------------------------------- -------- 58.7/73.8 MB 11.3 MB/s eta 0:00:02
#    -------------------------------- ------- 59.8/73.8 MB 11.1 MB/s eta 0:00:02
#    --------------------------------- ------ 61.1/73.8 MB 11.0 MB/s eta 0:00:02
#    --------------------------------- ------ 62.4/73.8 MB 10.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 63.4/73.8 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 64.5/73.8 MB 10.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 65.3/73.8 MB 10.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 66.3/73.8 MB 10.0 MB/s eta 0:00:01
#    ------------------------------------ --- 67.6/73.8 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------- -- 68.4/73.8 MB 9.7 MB/s eta 0:00:01
#    ------------------------------------- -- 69.5/73.8 MB 9.6 MB/s eta 0:00:01
#    -------------------------------------- - 70.5/73.8 MB 9.5 MB/s eta 0:00:01
#    -------------------------------------- - 71.8/73.8 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------  72.9/73.8 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  73.7/73.8 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  73.7/73.8 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  73.7/73.8 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  73.7/73.8 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  73.7/73.8 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  73.7/73.8 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 73.8/73.8 MB 7.9 MB/s eta 0:00:00
# Downloading pyqt6_sip-13.10.2-cp313-cp313-win_amd64.whl (53 kB)
# Installing collected packages: PyQt6-Qt6, PyQt6-sip, PyQt6
#
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    ---------------------------------------- 0/3 [PyQt6-Qt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    -------------------------- ------------- 2/3 [PyQt6]
#    ---------------------------------------- 3/3 [PyQt6]
#
# Successfully installed PyQt6-6.9.1 PyQt6-Qt6-6.9.1 PyQt6-sip-13.10.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import traceback
from gesture_engine import complete_engine # Import the global instance

def run_gesture_system():
    """
    Initializes and runs the complete gesture control system.
    """
    print("🎬 STARTING COMPLETE GESTURE CONTROL SYSTEM")
    print("=" * 50)
    
    print("🔧 Initializing gesture engine...")
    if not complete_engine.initialize():
        print("❌ Engine initialization failed! Check model paths or camera access.")
        return
    
    print("✅ Engine initialized successfully!")
    print("\n--- CONTROLS ---")
    print("  Q: Quit")
    print("  SPACE: Start / Stop Engine")
    print("  P: Pause / Resume Engine")
    print("\n--- APP MODES ---")
    print("  0: Disable Mode")
    print("  1: PowerPoint Mode")
    print("  2: Media Player Mode")
    print("  3: Browser Mode")
    print("------------------\n")
    
    # Start the engine
    complete_engine.start()
    
    try:
        while True:
            # The engine provides the fully processed and rendered frame
            processed_frame = complete_engine.get_frame_with_complete_processing()
            
            if processed_frame is not None:
                cv2.imshow("Gesture Control System", processed_frame)
            else:
                # This can happen if the camera is disconnected
                print("❌ Engine returned no frame. Exiting loop.")
                break
            
            key = cv2.waitKey(1) & 0xFF
            
            if key == ord('q'):
                print("...Exiting")
                break
            
            elif key == ord(' '): # Start/Stop
                if complete_engine.running and not complete_engine.paused:
                    complete_engine.stop()
                else:
                    complete_engine.start()
            
            elif key == ord('p'): # Pause/Resume
                if complete_engine.paused:
                    complete_engine.resume()
                else:
                    complete_engine.pause()
            
            # --- Mode Switching ---
            elif key == ord('0'):
                complete_engine.switch_mode('disabled')
            elif key == ord('1'):
                complete_engine.switch_mode('ppt_mode')
            elif key == ord('2'):
                complete_engine.switch_mode('media_mode')
            elif key == ord('3'):
                complete_engine.switch_mode('browser_mode')

    except Exception as e:
        print(f"\n🚨 An error occurred during the main loop: {e}")
        traceback.print_exc()
        
    finally:
        print("⏹️ Stopping engine and cleaning up...")
        complete_engine.stop()
        cv2.destroyAllWindows()
        print("✅ System shut down gracefully.")

# Run the system
run_gesture_system()
# Out:
# ✅ Configuration loaded from gesture_config.json
# 🎬 STARTING COMPLETE GESTURE CONTROL SYSTEM
# ==================================================
# 🔧 Initializing gesture engine...
# 🔧 Initializing Complete Gesture Engine...
# ✅ All models initialized successfully
# ✅ Camera 0 working!
# ✅ Complete Gesture Engine initialized!
# ✅ Engine initialized successfully!
#
# --- CONTROLS ---
#   Q: Quit
#   SPACE: Start / Stop Engine
#   P: Pause / Resume Engine
#
# --- APP MODES ---
#   0: Disable Mode
#   1: PowerPoint Mode
#   2: Media Player Mode
#   3: Browser Mode
# ------------------
#
# ▶️ Complete Engine started!
# 🔍 STATE: NO_HANDS → ONE_HAND_SEARCHING
# 🔄 STATE: ONE_HAND_SEARCHING → NO_HANDS
# 🔍 STATE: NO_HANDS → ONE_HAND_SEARCHING
# 🔄 STATE: ONE_HAND_SEARCHING → NO_HANDS
# 🔍 STATE: NO_HANDS → ONE_HAND_SEARCHING
# 🔄 STATE: ONE_HAND_SEARCHING → NO_HANDS
# 🔍 STATE: NO_HANDS → ONE_HAND_SEARCHING
# ⏰ STATE: ONE_HAND_SEARCHING → ONE_HAND_STABLE
# 🔄 STATE: ONE_HAND_STABLE → NO_HANDS
# 🎉 STATE: NO_HANDS → TWO_HANDS
# 🔄 STATE: TWO_HANDS → NO_HANDS
# 🔍 STATE: NO_HANDS → ONE_HAND_SEARCHING
# 🎉 STATE: ONE_HAND_SEARCHING → TWO_HANDS
# 🔄 STATE: TWO_HANDS → NO_HANDS
# ...Exiting
# ⏹️ Stopping engine and cleaning up...
# ⏹️ Complete Engine stopped!
# ✅ System shut down gracefully.
